# %% [markdown]
# <a href="https://colab.research.google.com/github/cdspassos/Spoon-Knife/blob/master/Exemplo1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#Isto é um comentário!
"""
Isto
É
Um Parágrafo comentado
"""

print("Bom dia!")

#num1 = 4
#num2 = 4

try:
  num1 = int(input("Introduza o primeiro número a somar: "))
  num2 = int(input("Introduza o segundo número a somar: "))

  soma = num1 + num2

  #print("O valor da soma é: ", soma)
  print(f"O valor da soma entre {num1} e {num2} é: {soma}")
except ValueError:
  print("Erro! O número deve ser um valor inteiro! ")
# Out:
# Bom dia!
# Introduza o primeiro número a somar: 3
# Introduza o segundo número a somar: 4
# O valor da soma entre 3 e 4 é: 7
